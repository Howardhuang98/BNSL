# %% [markdown]
# # Example for running DLBN

# %%
import networkx as nx
from dlbn import estimators
import pandas as pd

# %% [markdown]
# prepare data and initialize estimator.
# the result are stored as "run_result.csv"

# %%
data = pd.read_excel(r"../datasets/simple.xlsx")
est = estimators.estimator(data,"run_result.csv")

# %% [markdown]
# est.run() begins learning process;
# use nx.draw() to visualize result.

# %%
result = est.run()
nx.draw(result,with_labels=True)
# Out:
# adding cost: 100%|██████████| 192/192 [00:07<00:00, 25.93it/s]
